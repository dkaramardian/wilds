# %%
from wilds.common.data_loaders import get_eval_loader
from wilds import get_dataset
from wilds.common.data_loaders import get_train_loader
import torchvision.transforms as transforms

# Load the full dataset, and download it if necessary
dataset = get_dataset(dataset="camelyon17", download=True)

# Get the test set
test_data = dataset.get_subset(
    "test",
    transform=transforms.Compose(
        [transforms.Resize((224, 224)), transforms.ToTensor()]
    ),
)

# Prepare the data loader
test_loader = get_eval_loader("standard", test_data, batch_size=16)

# Get predictions for the full test set
for x, y_true, metadata in test_loader:
    y_pred = model(x)
    # Accumulate y_true, y_pred, metadata

# Evaluate
dataset.eval(all_y_pred, all_y_true, all_metadata)
# {'recall_macro_all': 0.66, ...}
# Out:
# Downloading dataset to data/camelyon17_v1.0...
# You can also download the dataset manually at https://wilds.stanford.edu/downloads.
# Downloading https://worksheets.codalab.org/rest/bundles/0xe45e15f39fb54e9d9e919556af67aabe/contents/blob/ to data/camelyon17_v1.0/archive.tar.gz
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/p_/fh0j8s1j7jbgk8xtn59nbl3h0000gn/T/ipykernel_71367/2872265539.py in <module>
#       5
#       6 # Load the full dataset, and download it if necessary
# ----> 7 dataset = get_dataset(dataset="camelyon17", download=True)
#       8
#       9 # Get the test set
#
# ~/Desktop/AI Safety Research/wilds/wilds/get_dataset.py in get_dataset(dataset, version, unlabeled, **dataset_kwargs)
#      38         else:
#      39             from wilds.datasets.camelyon17_dataset import Camelyon17Dataset
# ---> 40             return Camelyon17Dataset(version=version, **dataset_kwargs)
#      41
#      42     elif dataset == 'celebA':
#
# ~/Desktop/AI Safety Research/wilds/wilds/datasets/camelyon17_dataset.py in __init__(self, version, root_dir, download, split_scheme)
#      62     def __init__(self, version=None, root_dir='data', download=False, split_scheme='official'):
#      63         self._version = version
# ---> 64         self._data_dir = self.initialize_data_dir(root_dir, download)
#      65         self._original_resolution = (96,96)
#      66
#
# ~/Desktop/AI Safety Research/wilds/wilds/datasets/wilds_dataset.py in initialize_data_dir(self, root_dir, download)
#     339         # If the dataset exists at root_dir, then don't download.
#     340         if not self.dataset_exists_locally(data_dir, version_file):
# --> 341             self.download_dataset(data_dir, download)
#     342         return data_dir
#     343
#
# ~/Desktop/AI Safety Research/wilds/wilds/datasets/wilds_dataset.py in download_dataset(self, data_dir, download_flag)
#     378         try:
#     379             start_time = time.time()
# --> 380             download_and_extract_archive(
#     381                 url=download_url,
#     382                 download_root=data_dir,
#
# ~/Desktop/AI Safety Research/wilds/wilds/datasets/download_utils.py in download_and_extract_archive(url, download_root, extract_root, filename, md5, remove_finished, size)
#     293         filename = os.path.basename(url)
#     294
# --> 295     download_url(url, download_root, filename, md5, size)
#     296
#     297     archive = os.path.join(download_root, filename)
#
# ~/Desktop/AI Safety Research/wilds/wilds/datasets/download_utils.py in download_url(url, root, filename, md5, size)
#     106         try:
#     107             print('Downloading ' + url + ' to ' + fpath)
# --> 108             urllib.request.urlretrieve(
#     109                 url, fpath,
#     110                 reporthook=gen_bar_updater(size)
#
# ~/opt/anaconda3/lib/python3.9/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     266
#     267             while True:
# --> 268                 block = fp.read(bs)
#     269                 if not block:
#     270                     break
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in read(self, amt)
#     460             # Amount is given, implement using readinto
#     461             b = bytearray(amt)
# --> 462             n = self.readinto(b)
#     463             return memoryview(b)[:n].tobytes()
#     464         else:
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in readinto(self, b)
#     494
#     495         if self.chunked:
# --> 496             return self._readinto_chunked(b)
#     497
#     498         if self.length is not None:
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in _readinto_chunked(self, b)
#     599
#     600                 temp_mvb = mvb[:chunk_left]
# --> 601                 n = self._safe_readinto(temp_mvb)
#     602                 mvb = mvb[n:]
#     603                 total_bytes += n
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in _safe_readinto(self, b)
#     639                 n = self.fp.readinto(temp_mvb)
#     640             else:
# --> 641                 n = self.fp.readinto(mvb)
#     642             if not n:
#     643                 raise IncompleteRead(bytes(mvb[0:total_bytes]), len(b))
#
# ~/opt/anaconda3/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.9/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/lib/python3.9/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
